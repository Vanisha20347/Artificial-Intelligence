# %%
# !pip install pyswip
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !apt install swi-prolog
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# swi-prolog is already the newest version (7.6.4+dfsg-1build1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from pyswip import Prolog

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a837e9f2-86b1-430a-8a3d-d388ce3b1bec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a837e9f2-86b1-430a-8a3d-d388ce3b1bec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def nli(x):
    x = word_tokenize(x)  
    ps = PorterStemmer()  
    m = []               
    for i in x:
        m.append(ps.stem(i))
    if 'btech' in m:
        return 'btech'
    if 'mtech' in m:
        return 'mtech'
    if 'cse' in m:
        return 'cse'
    if 'csam' in m:
        return 'csam' 
    if 'ece' in m:
        return 'ece'
    if 'csss' in m:
        return 'csss'  
    if 'csd' in m:
        return 'csd' 
    if 'cb' in m:
        return 'cb'
    if (('big' in m) or ('data' in m) or ('mine' in m)) and ('healthcar' in m):
        return 'big_data_mining_in_healthcare' 
    if ('healthcar' in m) and (('machin' in m) or ('learn' in m)):
        return 'machine_learning_in_healthcare'
    if ('data' in m) or ('analyst' in m) or ('machin' in m):
        return 'data_analyst/machine_learning'   
    if ('secur' in m) or ('privaci' in m):
        return 'security_and_privacy_engineer' 
    if ('mobil' in m) or ('applic' in m):
        return 'mobile_application_developer' 
    if ('ai' in m) or ('machin' in m):
        return 'in_ai/machine_learning'
    if ('softwar' in m) or ('develop' in m):
        return 'software_developer'       
    if ('higher' in m) or ('studi' in m) or ('math' in m):
        return 'higher_studies_in_maths'
    if ('imag' in m) or ('process' in m):
        return 'image_processing'  
    if ('virtual' in m) or ('realiti' in m):
        return 'in_virtual_reality'    
    if ('financ' in m) or ('econom' in m):
        return 'finance_and_economics' 
    if ('hardwar' in m) or ('profil' in m):
        return 'hardware_profile' 
    if ('wireless' in m) or ('network' in m) or ('engin' in m):
        return 'wireless_network_engineer'

# %%
print('-------------------------------------------------------------------------------')
print('                    Welcome To Elective Advisory System')
print('-------------------------------------------------------------------------------')
print('Are you currently persuing B.Tech. or M.Tech.?')
d = input()
d = nli(d)
if d == 'btech':
  print('What is your branch? (CSE,CSAM,CSD,CSSS,ECE)')
  b = input()
  b = nli(b)
elif d == 'mtech':
  print('What is your branch? (CSE,ECE,CB)')
  b = input()
  b = nli(b)
else:
  print('No such degree exists')
# Out:
# -------------------------------------------------------------------------------
#                     Welcome To Elective Advisory System
# -------------------------------------------------------------------------------
# Are you currently persuing B.Tech. or M.Tech.?
# btech
# What is your branch? (CSE,CSAM,CSD,CSSS,ECE)
# cse

# %%
f = open("file.pl", 'w')

# %%
if d == 'btech':
  f.write("allocation(degree({})).\n".format(d))
if d == 'mtech':
  f.write("allocation(degree({})).\n".format(d))
if b == 'cse':
  f.write("allocation(branch({})).\n".format(b))
if b == 'ece':
  f.write("allocation(branch({})).\n".format(b))
if b == 'csam':
  f.write("allocation(branch({})).\n".format(b))
if b == 'csss':
  f.write("allocation(branch({})).\n".format(b))
if b == 'csd':
  f.write("allocation(branch({})).\n".format(b))
if b == 'cb':
  f.write("allocation(branch({})).\n".format(b))

# %%
if d == 'btech' and b == 'cse':
  print('What Carrer Do You Want To Persue From The Given Choices:- ')
  print('1. Data Analyst/Machine Learning')
  print('2. Security and Privacy Engineer')
  print('3. Mobile Application Developer')
  x = input()
  x = nli(x)
  f.write("allocation(career({})).\n".format(x))

  print('Do you have interest in security and privacy?')
  x = input()
  f.write("allocation(security({})).\n".format(x))

  print('Do you have interest in computer architechture?')
  x = input()
  f.write("allocation(archi({})).\n".format(x)) 
  
  print('Do you have interest in data analysis and machine learning?')
  x = input()
  f.write("allocation(ml({})).\n".format(x))  
  f.write("allocation(da({})).\n".format(x))  

  print('Do you have interest in designing, development and evaluation of mobile applications?')
  x = input()
  f.write("allocation(mobile({})).\n".format(x)) 
  f.close()

elif d == 'btech' and b == 'ece':
  print('What Carrer Do You Want To Persue From The Given Choices:- ')
  print('1. In AI/Machine Learning')
  print('2. Finance and Economics')
  print('3. Hardware Profile')
  x = input()
  x = nli(x)
  f.write("allocation(career({})).\n".format(x))

  print('Do you want to explore artificial intelligence and machine learning domain?')
  x = input()
  f.write("allocation(ml({})).\n".format(x))

  print('Do you want to learn about signal processing and signal analysis?')
  x = input()
  f.write("allocation(signal({})).\n".format(x)) 
  
  print('Do you want interest in leaning about communication systems?')
  x = input()
  f.write("allocation(comm({})).\n".format(x))  

  print('Do you have interest in finanace and global economics?')
  x = input()
  f.write("allocation(eco({})).\n".format(x)) 

  print('Do you have interest in hardware stuff and learning how it works?')
  x = input()
  f.write("allocation(hardware({})).\n".format(x))   

  print('Do you want to learn about IoT(Internet Of Things) and explore that field?')
  x = input()
  f.write("allocation(iot({})).\n".format(x))   
  f.close()

elif d == 'btech' and b == 'csam':
  print('What Carrer Do You Want To Persue From The Given Choices:- ')
  print('1. In AI/Machine Learning')
  print('2. Software Developer')
  print('3. Higher Studies in Maths')
  x = input()
  x = nli(x)
  f.write("allocation(career({})).\n".format(x))

  print('Do you want to discover and explore Artificial Intelligence?')
  x = input()
  f.write("allocation(ai({})).\n".format(x))

  print('Do you want to dig deep in maths and learn the concepts of Number Theory?')
  x = input()
  f.write("allocation(nt({})).\n".format(x)) 
  
  print('Do you want to learn about signal processing and signal analysis?')
  x = input()
  f.write("allocation(signal({})).\n".format(x))  

  print('Do you have interest in OOPs(Object Oriented Programing) and want to learn various techniques such as abstration, encapsulation and inheritance?')
  x = input()
  f.write("allocation(ap({})).\n".format(x)) 
  f.close()

elif d == 'btech' and b == 'csss':
  print('What Carrer Do You Want To Persue From The Given Choices:- ')
  print('1. In AI/Machine Learning')
  print('2. Image Processing')
  print('3. Security and Privacy Engineer')
  x = input()
  x = nli(x)
  f.write("allocation(career({})).\n".format(x))

  print('Do you want to discover the machine learning field and try out how one can make machine learn and predict data?')
  x = input()
  f.write("allocation(ml({})).\n".format(x))

  print('Do you have interest in deep learning?')
  x = input()
  f.write("allocation(dl({})).\n".format(x)) 
  
  print('Do you want to learn how one can privacy and sercurity systems in social media world?')
  x = input()
  f.write("allocation(sm({})).\n".format(x))  

  print('Do you have interest in big data analytics?')
  x = input()
  f.write("allocation(bd({})).\n".format(x)) 

  print('Do you have in image processing and transformation?')
  x = input()
  f.write("allocation(ip({})).\n".format(x)) 

  print('Do you have interest in optimization problems and mathematical theory?')
  x = input()
  f.write("allocation(co({})).\n".format(x)) 
  f.close()

elif d == 'btech' and b == 'csd':
  print('What Carrer Do You Want To Persue From The Given Choices:- ')
  print('1. In AI/Machine Learning')
  print('2. Image Processing')
  print('3. In Virtual Reality')
  x = input()
  x = nli(x)
  f.write("allocation(career({})).\n".format(x))

  print('Do you have in image processing and transformation?')
  x = input()
  f.write("allocation(ip({})).\n".format(x))

  print('Do you want to discover the machine learning field and try out how one can make machine learn and predict data?')
  x = input()
  f.write("allocation(ml({})).\n".format(x)) 
  
  print('Do you have interest in computer graphics including necessary mathematics and algorithms?')
  x = input()
  f.write("allocation(cg({})).\n".format(x))  

  print('Do you want interest in visualization of data?')
  x = input()
  f.write("allocation(dv({})).\n".format(x)) 

  print('Do you want to learn computer vision?')
  x = input()
  f.write("allocation(cv({})).\n".format(x)) 

  print('Do you have interest in virtual reality?')
  x = input()
  f.write("allocation(vr({})).\n".format(x)) 

  print('Do you have interest in animation?')
  x = input()
  f.write("allocation(a({})).\n".format(x)) 
  f.close()
  
elif d == 'mtech' and b == 'cse':
  print('What Carrer Do You Want To Persue From The Given Choices:- ')
  print('1. Software Developer')
  print('2. Wireless Network Engineer')
  print('3. Mobile Application Developer')
  x = input()
  x = nli(x)
  f.write("allocation(career({})).\n".format(x))

  print('Do you have interest in designing, development and evaluation of mobile applications?')
  x = input()
  f.write("allocation(mobile({})).\n".format(x))

  print('Do you have interest in computer architechture?')
  x = input()
  f.write("allocation(archi({})).\n".format(x)) 
  
  print('Do you interest in learning advanced/high level algorithms?')
  x = input()
  f.write("allocation(aa({})).\n".format(x))  
  f.write("allocation(ga({})).\n".format(x))  

  print('Are you interested in learning about compilers and how they actually work?')
  x = input()
  f.write("allocation(compilers({})).\n".format(x)) 

  print('Do you have interest knowing how wireless networks work?')
  x = input()
  f.write("allocation(wn({})).\n".format(x)) 
  f.close()

elif d == 'mtech' and b == 'ece':
  print('What Carrer Do You Want To Persue From The Given Choices:- ')
  print('1. In AI/Machine Learning')
  print('2. Image Processing')
  print('3. Wireless Network Engineer')
  x = input()
  x = nli(x)
  f.write("allocation(career({})).\n".format(x))

  print('Do you have interest in image processing and transformation?')
  x = input()
  f.write("allocation(ip({})).\n".format(x))

  print('Do you want to discover the machine learning field and try out how one can make machine learn and predict data?')
  x = input()
  f.write("allocation(ml({})).\n".format(x)) 
  
  print('Do you have interest in Modelling of 5G network?')
  x = input()
  f.write("allocation(mod({})).\n".format(x))  

  print('Are you interested in learning more about wireless communication?')
  x = input()
  f.write("allocation(wc({})).\n".format(x)) 

  print('Do you have interest in computer networks and how it actually works?')
  x = input()
  f.write("allocation(cn({})).\n".format(x)) 
  f.close()

elif d == 'mtech' and b == 'cb':
  print('What Carrer Do You Want To Persue From The Given Choices:- ')
  print('1. Big Data Mining In Healthcare')
  print('2. Machine Learning in Healthcare')
  x = input()
  x = nli(x)
  f.write("allocation(career({})).\n".format(x))

  print('Are you interested in learning big data mining for its application in healthcare?')
  x = input()
  f.write("allocation(bdh({})).\n".format(x))

  print('Do you have a interest in discovering more about genes and its cure in various disesases?')
  x = input()
  f.write("allocation(g({})).\n".format(x)) 
  
  print('Are you willing to learn machine learning in order to apply it in healthcare system and improvise it?')
  x = input()
  f.write("allocation(mlba({})).\n".format(x))  

  print('Are you interest in studying about network science?')
  x = input()
  f.write("allocation(ns({})).\n".format(x)) 
  f.close()
# Out:
# What Carrer Do You Want To Persue From The Given Choices:-
# 1. Data Analyst/Machine Learning
# 2. Security and Privacy Engineer
# 3. Mobile Application Developer
# machine
# Do you have interest in security and privacy?
# no
# Do you have interest in computer architechture?
# no
# Do you have interest in data analysis and machine learning?
# yes
# Do you have interest in designing, development and evaluation of mobile applications?
# yes

# %%
swipl = Prolog()
swipl.consult("Assignment1.pl")
l = list(swipl.query("func(X)"))
print(l)
# Out:
# [{'X': 'Mobile Computing'}, {'X': 'Data Analytics'}, {'X': 'Data Analytics'}, {'X': 'Image Analysis & Machine Learning'}, {'X': 'none'}]
